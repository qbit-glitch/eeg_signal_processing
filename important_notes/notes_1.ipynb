# %% [markdown]
# # Notes - 1
#
# ## Important Keywords :
#
# **Theoretical POV**
#
# - STIM Channels
# - DC Shifts / squarewave pulses
# - Morlet Wavelets
# - Cortical Surface
#
# **Projecting the Sensor data into Subject's source space**:
#
# - Dynamic Statistical Parametric Mapping
# - Dipole Fitting
# - Beamformers
#
# **Plotting :**
#
# - Power Spectral Density (PSD)
# - Cross Spectral Density
#
# **Technicalities :**
#
# - Inverse Operator
# - Forward Solution
# - Covariance of Sensor Measurements
# - Signal-to-Noise ratio
# - Source Time Course (STC)
#
# **Preprocessing Techniques**:
#
# - Maxwell filtering
# - Signal-Space Projection
# - Independent Component Analysis
# - Filtering
# - Downsampling
#
# **Others**
# - NeuroMag Systems
# - Dorso-Frontal Electrodes
# - Minimum Norm Estimation (MNE)
# - Inverse Problem (underdetermined)
# - Regularization Parameter (specify the relative smoothness of the current estimates in terms of signal to noise ratio)
# - Noise -> baseline activity level accross all of cortex

# %% [markdown]
# ## Make a environment with a specific version of python

# %%
ls -l /opt/homebrew/bin/python3*
/opt/homebrew/bin/python3.10 -m venv_2
